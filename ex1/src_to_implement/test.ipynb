# %% [markdown]
# # Feed Forward Neural Network
#
# In this exercise we implement a feed forward neural network from scratch. The goal is
# to understand how the most basic form of a neural network works without using DL frameworks like
# PyTorch and TensorFlow.

# %% [markdown]
# ## 1. Basic Optimizer
#
# In a neural network, the optimizer is the algorithm responsible for updating the network’s weights and biases to reduce error.
# There are different optimizers out there, but the most basic one is SGD (stochastic gradient descent).

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
